# %%
print('Óla, Cristiano! Estou começando minha jornada em TI.')
# Out:
# Óla, Cristiano! Estou começando minha jornada em TI.

# %%
nome = 'Cristiano'
idade = 40
print('Meu nome é', nome, 'E eu tenho', idade, 'anos'  )
# Out:
# Meu nome é Cristiano E eu tenho 40 anos

# %%
# Calculadora Simples
a = 10
b = 5
print('Soma', a + b)
print('Subtração', a - b)
print('Multiplicação', a * b)
print('Divisão', a / b)
# Out:
# Soma 15
# Subtração 5
# Multiplicação 50
# Divisão 2.0

# %%
x = 15
y = 4
print('Soma', x + y)
print('Diferença', x - y)
print('produto', x * y)
print('Divisão', x / y)
# Out:
# Soma 19
# Diferença 11
# produto 60
# Divisão 3.75

# %%
idade = 40
if idade >= 18:
    print('Você é maior de idade.')
else:
    print('Você é menor de idade.')
# Out:
# Você é maior de idade.

# %%
tarefas = ['Estudar Python', 'Praticar HTML', 'Assistir au CS50']
for t in tarefas:
    print('Minha tarefa de hoje', t)
# Out:
# Minha tarefa de hoje Estudar Python
# Minha tarefa de hoje Praticar HTML
# Minha tarefa de hoje Assistir au CS50
